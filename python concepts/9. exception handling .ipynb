# %% [markdown]
# In Python, errors that occur during the execution are called exceptions. The causes of exceptions mainly come from the environment where the code executes. For example:
#
# Reading a file that doesn’t exist.
# Connecting to a remote server that is offline.
# Bad user inputs.
# When an exception occurs, the program doesn’t handle it automatically. This results in an error message.
#
# ![image.png](attachment:8b07633a-53f2-4aa0-8f1e-4e214a095229.png)

# %%
try:
    print(10 + '5')
except:
    print('Something went wrong')
# Out:
# Something went wrong

# %%
try:
    name = input('Enter your name:')
    year_born = input('Year you were born:')
    age = 2019 - year_born
    print(f'You are {name}. And your age is {age}.')
except:
    print('Something went wrong')
# Out:
# Enter your name: kiran
# Year you were born: 2002
# Something went wrong

# %%
try:
    user_input = int(input("Enter a number: "))
except ValueError:
    print("Please enter a valid number.")
else:
    print(f"Success! You entered: {user_input}")
# Out:
# Enter a number:  123
# Success! You entered: 123

# %%
# file not found error 
try:
    with open("non_existent_file.txt", "r") as file:
        data = file.read()
except FileNotFoundError as e:
    print(f"Error: {e}")
# Out:
# Error: [Errno 2] No such file or directory: 'non_existent_file.txt'

# %%
a = 10
b = 0

try:
    c = a / b
    print(c)
except ZeroDivisionError as error:
    print("error:",error)
finally:
    print('executed finally block.')
# Out:
# error: division by zero
# executed finally block.

# %%
a = 10
b = 0

try:
    c = a / b
    print(c)
finally:
    print('Finishing up.')

# %%
try:
    file = open("data.txt", "r")
    data = file.read()
finally:
    print("File closed.")
    file.close()

# %%
def validate_email(email):
    if "@" not in email:
        raise ValueError(f"The email ({email}) provided is Invalid email ")
    return True

try:
    validate_email("fsf.com")
except ValueError as e:
    print(f"Error: {e}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 7
#       4     return True
#       6 try:
# ----> 7     validate_email("fsf.com")
#       8 except ValueError as e:
#       9     print(f"Error: {e}")
#
# Cell In[31], line 3, in validate_email(email)
#       1 def validate_email(email):
#       2     if "@" not in email:
# ----> 3         raise ValueErrorss(f"The email ({email}) provided is Invalid email ")
#       4     return True
#
# NameError: name 'ValueErrorss' is not defined

# %%
try:
    name = input('Enter your name:')
    year_born = input('Year you were born:')
    age = 2024 - int(year_born)
    print(f'You are {name}. And your age is {age}.')
except TypeError:
    print('Type error occured')
except ValueError:
    print('Value error occured')
except ZeroDivisionError:
    print('zero division error occured')
else: print ("try block executed sucessfully and no error ")
finally: print("task is compleated ")
# Out:
# Enter your name: kiran
# Year you were born: 2001
# You are kiran. And your age is 23.
# try block executed sucessfully and no error
# task is compleated
